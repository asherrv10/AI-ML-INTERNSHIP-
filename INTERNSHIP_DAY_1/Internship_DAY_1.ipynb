# %% [markdown]
# # Internship Journal: Day 1
# ## Task: Data Exploration and Preprocessing (Zudio & Titanic Datasets)
#
# In this session, I performed the following:
# 1. Loaded and explored sales data.
# 2. Handled missing values using Mean, Median, and Mode imputation.
# 3. Visualized data distributions using Boxplots.
# 4. Implemented Feature Encoding (Label Encoding, One-Hot Encoding, and Ordinal Mapping).

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Zudio_sales_data.csv")

# %%
df.head()
# Out:
#    Store Country          State      City Category Clothing Type  \
# 0  Zudio   India      Karnataka     Jalna    Women       Dresses
# 1  Zudio   India        Gujarat     Patna     Kids        Skirts
# 2  Zudio   India  Uttar Pradesh   Kolkata      Men       Hoodies
# 3  Zudio   India    West Bengal   Kolkata    Women       Dresses
# 4  Zudio   India    West Bengal  Guwahati      Men       Dresses
#
#    Store Number  Postal Code Store Type Store Open Date  ...  \
# 0            30       411084      Owned      2022-06-04  ...
# 1            48       404562      Owned      2020-12-19  ...
# 2            97       437773     Rented      2023-09-04  ...
# 3            93       431725      Owned      2024-04-11  ...
# 4            51       415370      Owned      2022-05-29  ...
#
#    Security Features Order ID  Order Date     Month Customer ID  \
# 0              Alarm    88240  2024-11-06  November      233084
# 1              Alarm    78145  2024-06-17      June      926472
# ...

# %%
df.tail()
# Out:
#       Store Country          State        City Category Clothing Type  \
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# 7894            32       431437      Owned      2024-04-24  ...
# 7895            52       424643      Owned      2024-02-03  ...
# 7896            81       412057      Owned      2021-04-11  ...
# 7897            58       405203     Rented      2022-06-17  ...
# 7898            20       429823      Owned      2023-02-08  ...
#
#       Security Features Order ID  Order Date      Month Customer ID  \
# 7894        CCTV, Alarm    39056  2024-09-27  September      591993
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7899 entries, 0 to 7898
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      7899 non-null   object
#  1   Country                    7899 non-null   object
#  2   State                      7899 non-null   object
#  3   City                       7899 non-null   object
#  4   Category                   7899 non-null   object
#  5   Clothing Type              7899 non-null   object
#  6   Store Number               7899 non-null   int64
#  7   Postal Code                7899 non-null   int64
#  8   Store Type                 7899 non-null   object
#  9   Store Open Date            7899 non-null   object
#  10  Selling Area Size (sq ft)  7899 non-null   int64
#  11  Store Manager              7899 non-null   object
#  12  Manager ID                 7899 non-null   object
# ...

# %%
df.shape
# Out:
# (7899, 28)

# %%
df.dtypes
# Out:
# Store                         object
# Country                       object
# State                         object
# City                          object
# Category                      object
# Clothing Type                 object
# Store Number                   int64
# Postal Code                    int64
# Store Type                    object
# Store Open Date               object
# Selling Area Size (sq ft)      int64
# Store Manager                 object
# Manager ID                    object
# Store Address                 object
# Contact Information           object
# Operating Hours               object
# Staff Count                    int64
# Parking Availability          object
# Security Features             object
# Order ID                       int64
# Order Date                    object
# Month                         object
# Customer ID                    int64
# Customer Name                 object
# Product ID                     int64
# ...

# %%
df.describe()
# Out:
#        Store Number    Postal Code  Selling Area Size (sq ft)  Staff Count  \
# count   7899.000000    7899.000000                7899.000000  7899.000000
# mean      50.666034  419982.374984                1112.077478    11.504747
# std       29.095274   11695.237817                 193.239371     5.194722
# min        1.000000  400006.000000                 800.000000     3.000000
# 25%       25.000000  409841.000000                 950.000000     7.000000
# 50%       51.000000  419988.000000                1100.000000    12.000000
# 75%       76.000000  430258.000000                1300.000000    16.000000
# max      100.000000  439985.000000                1400.000000    20.000000
#
#            Order ID    Customer ID   Product ID        Price     Quantity  \
# count   7899.000000    7899.000000  7899.000000  7899.000000  7899.000000
# mean   54920.719965  549440.714521   602.069376  1761.113432     4.519433
# ...

# %%
df['Store']
# Out:
# 0       Zudio
# 1       Zudio
# 2       Zudio
# 3       Zudio
# 4       Zudio
#         ...
# 7894    Zudio
# 7895    Zudio
# 7896    Zudio
# 7897    Zudio
# 7898    Zudio
# Name: Store, Length: 7899, dtype: object

# %%
df[['Store','Country']]
# Out:
#       Store Country
# 0     Zudio   India
# 1     Zudio   India
# 2     Zudio   India
# 3     Zudio   India
# 4     Zudio   India
# ...     ...     ...
# 7894  Zudio   India
# 7895  Zudio   India
# 7896  Zudio   India
# 7897  Zudio   India
# 7898  Zudio   India
#
# [7899 rows x 2 columns]

# %%
df.isnull()
# Out:
#       Store  Country  State   City  Category  Clothing Type  Store Number  \
# 0     False    False  False  False     False          False         False
# 1     False    False  False  False     False          False         False
# 2     False    False  False  False     False          False         False
# 3     False    False  False  False     False          False         False
# 4     False    False  False  False     False          False         False
# ...     ...      ...    ...    ...       ...            ...           ...
# 7894  False    False  False  False     False          False         False
# 7895  False    False  False  False     False          False         False
# 7896  False    False  False  False     False          False         False
# 7897  False    False  False  False     False          False         False
# 7898  False    False  False  False     False          False         False
#
#       Postal Code  Store Type  Store Open Date  ...  Security Features  \
# ...

# %%
df.isnull().sum()
# Out:
# Store                           0
# Country                         0
# State                           0
# City                            0
# Category                        0
# Clothing Type                   0
# Store Number                    0
# Postal Code                     0
# Store Type                      0
# Store Open Date                 0
# Selling Area Size (sq ft)       0
# Store Manager                   0
# Manager ID                      0
# Store Address                   0
# Contact Information             0
# Operating Hours                 0
# Staff Count                     0
# Parking Availability            0
# Security Features            2038
# Order ID                        0
# Order Date                      0
# Month                           0
# Customer ID                     0
# Customer Name                   0
# Product ID                      0
# Price                           0
# Quantity                        0
# ...

# %%
df1 = pd.read_csv("/content/titanic uncleaned.csv")

# %%
df1.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df1['Age_mean_imputed'] = df1['Age'].fillna(df1['Age'].mean())

# %%
df1['Age_median_imputed'] = df1['Age'].fillna(df1['Age'].median())

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df1['Cabin_mode_imputed'] = df1['Cabin'].fillna(df1['Cabin'].mode()[0])

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df1[['Age','Age_mean_imputed','Age_median_imputed','Cabin_mode_imputed']]
# Out:
#       Age  Age_mean_imputed  Age_median_imputed Cabin_mode_imputed
# 0    34.5          34.50000                34.5    B57 B59 B63 B66
# 1    47.0          47.00000                47.0    B57 B59 B63 B66
# 2    62.0          62.00000                62.0    B57 B59 B63 B66
# 3    27.0          27.00000                27.0    B57 B59 B63 B66
# 4    22.0          22.00000                22.0    B57 B59 B63 B66
# ..    ...               ...                 ...                ...
# 413   NaN          30.27259                27.0    B57 B59 B63 B66
# 414  39.0          39.00000                39.0               C105
# 415  38.5          38.50000                38.5    B57 B59 B63 B66
# 416   NaN          30.27259                27.0    B57 B59 B63 B66
# 417   NaN          30.27259                27.0    B57 B59 B63 B66
#
# [418 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import  seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data = df1, x='Pclass', y='Age',palette='pastel')
# Out:
# /tmp/ipykernel_4084/691921394.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = df1, x='Pclass', y='Age',palette='pastel')
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
plt.title('Boxplot of Age by Passenger Class',fontsize=12)
plt.xlabel('Passenger Class',fontsize=12)
plt.ylabel('Age',fontsize=12)
# Out:
# Text(0, 0.5, 'Age')

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data = df1, x='Embarked', y='Fare',palette='pastel')
# Out:
# /tmp/ipykernel_4084/388428605.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = df1, x='Embarked', y='Fare',palette='pastel')
# <Axes: xlabel='Embarked', ylabel='Fare'>

# %%
plt.title('Boxplot of Fare by Embarked',fontsize=12)
plt.xlabel('Embarked',fontsize=12)
plt.ylabel('Fare',fontsize=12)
# Out:
# Text(0, 0.5, 'Fare')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
file_path = '/content/titanic uncleaned.csv'
titanic_data = pd.read_csv(file_path)

# %%
encoded_data = titanic_data.copy()

# %%
label_encoder = LabelEncoder()
encoded_data['Sex_Label'] = label_encoder.fit_transform(encoded_data['Sex'])

# %%
one_hot_encoded = titanic_data.copy()

# %%
encoded_data = titanic_data.copy()
label_encoder = LabelEncoder()
encoded_data['Sex_Label'] = label_encoder.fit_transform(encoded_data['Sex'])


one_hot_df = pd.get_dummies(encoded_data['Embarked'], prefix='Embarked')
encoded_data = pd.concat([encoded_data, one_hot_df], axis=1)


pclass_mapping = {1: 'First', 2: 'Second', 3: 'Third'}
encoded_data['Pclass_Category'] = encoded_data['Pclass'].map(pclass_mapping)


print(encoded_data[['Sex', 'Sex_Label', 'Embarked', 'Embarked_Q', 'Embarked_S', 'Embarked_C', 'Pclass', 'Pclass_Category']].head())
# Out:
#       Sex  Sex_Label Embarked  Embarked_Q  Embarked_S  Embarked_C  Pclass  \
# 0    male          1        Q        True       False       False       3
# 1  female          0        S       False        True       False       3
# 2    male          1        Q        True       False       False       2
# 3    male          1        S       False        True       False       3
# 4  female          0        S       False        True       False       3
#
#   Pclass_Category
# 0           Third
# 1           Third
# 2          Second
# 3           Third
# 4           Third
